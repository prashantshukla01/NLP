# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (4.66.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
corpus =""" Hello Welcome  to Prashant Shukla's NLP tutorials.
Please do watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
#  Hello Welcome  to Prashant Shukla's NLP tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
##tokenization 

## sentence --> paragraphs 
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/prashantshukla/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
sent_tokenize(corpus)
# Out:
# [" Hello Welcome  to Prashant Shukla's NLP tutorials.",
#  'Please do watch the entire course!',
#  'to become expert in NLP.']

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
#  Hello Welcome  to Prashant Shukla's NLP tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %%
### word tokenization
## paragraphs --> words

## sentences --> words

from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'Prashant',
#  'Shukla',
#  "'s",
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'Prashant',
#  'Shukla',
#  "'",
#  's',
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'Prashant',
#  'Shukla',
#  "'s",
#  'NLP',
#  'tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
