# %% [markdown]
# ## Stemming
# Stemming is the process of reducing a word to its word stem that affixes to
# suffixes and prefixes or to the roots of words known as a lemma. Stemming is
# important in natural language understanding (NLU) and natural language processing (NLP).

# %%
# Classification Problem
# Comments of product is a positive review or negative review
# Reviews----> eating, eat,eaten [going,gone,goes]--->go
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# ## PorterStemmer

# %%
from nltk.stem import PorterStemmer
stemming = PorterStemmer()

# %%
for word in words:
    print(f"Original Word: {word} ---> Stemmed Word: {stemming.stem(word)}")
# Out:
# Original Word: eating ---> Stemmed Word: eat
# Original Word: eats ---> Stemmed Word: eat
# Original Word: eaten ---> Stemmed Word: eaten
# Original Word: writing ---> Stemmed Word: write
# Original Word: writes ---> Stemmed Word: write
# Original Word: programming ---> Stemmed Word: program
# Original Word: programs ---> Stemmed Word: program
# Original Word: history ---> Stemmed Word: histori
# Original Word: finally ---> Stemmed Word: final
# Original Word: finalized ---> Stemmed Word: final

# %%
stemming.stem("congratulations")
# Out:
# 'congratul'

# %%
stemming.stem("sitting")
# Out:
# 'sit'

# %% [markdown]
# ## RegexpStemmer class
#
# NLTK has RegexpStemmer class with the help of which we can easily implement Regular Expression Stemmer algorithms. It basically takes a single regular expression and removes any prefix or suffix that matches the expression. Let us see an example

# %%
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer('ing$|s$|ed$| able$', min=4)  # removing ing,s,ed from the words

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer.stem('ingeating')
# Out:
# 'ingeat'

# %% [markdown]
# ## Snowball Stemmer
#
# It is a stemming algorithm which is also known as the Porter2 stemming algorithm as it is a better version of the Porter Stemmer since some issues of it were fixed in this stemmer.

# %%
from nltk.stem import SnowballStemmer

# %%
snowballstemmer=SnowballStemmer('english')

# %%
for word in words:
    print(f"Original Word: {word} ---> Stemmed Word: {snowballstemmer.stem(word)}")
# Out:
# Original Word: eating ---> Stemmed Word: eat
# Original Word: eats ---> Stemmed Word: eat
# Original Word: eaten ---> Stemmed Word: eaten
# Original Word: writing ---> Stemmed Word: write
# Original Word: writes ---> Stemmed Word: write
# Original Word: programming ---> Stemmed Word: program
# Original Word: programs ---> Stemmed Word: program
# Original Word: history ---> Stemmed Word: histori
# Original Word: finally ---> Stemmed Word: final
# Original Word: finalized ---> Stemmed Word: final

# %%
stemming.stem("fairly"),stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snowballstemmer.stem("fairly"),snowballstemmer.stem("sportingly")
# Out:
# ('fair', 'sport')

# %%
snowballstemmer.stem('goes')
# Out:
# 'goe'
